# %% [markdown]
# ANÁLISE DISCRIMINANTE
# Maximiza as diferenas entre os grupos

# %%
import numpy as np


class LDA:
    def __init__(self, n_components):
        self.n_components = n_components
        self.linear_discriminants = None

    def fit(self, X, y):
        n_features = X.shape[1]
        class_labels = np.unique(y)

        # Within class scatter matrix:
        # SW = sum((X_c - mean_X_c)^2 )

        # Between class scatter:
        # SB = sum( n_c * (mean_X_c - mean_overall)^2 )

        mean_overall = np.mean(X, axis=0)
        SW = np.zeros((n_features, n_features))
        SB = np.zeros((n_features, n_features))
        for c in class_labels:
            X_c = X[y == c]
            mean_c = np.mean(X_c, axis=0)
            # (4, n_c) * (n_c, 4) = (4,4) -> transpose
            SW += (X_c - mean_c).T.dot((X_c - mean_c))

            # (4, 1) * (1, 4) = (4,4) -> reshape
            n_c = X_c.shape[0]
            mean_diff = (mean_c - mean_overall).reshape(n_features, 1)
            SB += n_c * (mean_diff).dot(mean_diff.T)

        # Determine SW^-1 * SB
        A = np.linalg.inv(SW).dot(SB)
        # Get eigenvalues and eigenvectors of SW^-1 * SB
        eigenvalues, eigenvectors = np.linalg.eig(A)
        # -> eigenvector v = [:,i] column vector, transpose for easier calculations
        # sort eigenvalues high to low
        eigenvectors = eigenvectors.T
        idxs = np.argsort(abs(eigenvalues))[::-1]
        eigenvalues = eigenvalues[idxs]
        eigenvectors = eigenvectors[idxs]
        # store first n eigenvectors
        self.linear_discriminants = eigenvectors[0 : self.n_components]

    def transform(self, X):
        # project data
        return np.dot(X, self.linear_discriminants.T)


# Testing
if __name__ == "__main__":
    # Imports
    import matplotlib.pyplot as plt
    from sklearn import datasets

    data = datasets.load_iris()
    X, y = data.data, data.target


    # Project the data onto the 2 primary linear discriminants
    lda = LDA(2)
    lda.fit(X, y)
    X_projected = lda.transform(X)

    print("Shape of X:", X.shape)
    print("Shape of transformed X:", X_projected.shape)

    x1, x2 = X_projected[:, 0], X_projected[:, 1]

    plt.scatter(
        x1, x2, c=y, edgecolor="none", alpha=0.8, cmap=plt.cm.get_cmap("viridis", 3)
    )

    plt.xlabel("Linear Discriminant 1")
    plt.ylabel("Linear Discriminant 2")
    plt.colorbar()
    plt.show()
# Out:
# Shape of X: (150, 4)
# Shape of transformed X: (150, 2)
# /tmp/ipykernel_8143/394108141.py:72: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   x1, x2, c=y, edgecolor="none", alpha=0.8, cmap=plt.cm.get_cmap("viridis", 3)

# %%
import numpy as np

class ExponentialDiscriminationML:
    def __init__(self, lambda1, lambda2, threshold):
        self.lambda1 = lambda1
        self.lambda2 = lambda2
        self.threshold = threshold
    
    def pdf(self, x, lambda_):
        return lambda_ * np.exp(-lambda_ * x)
    
    def classify(self, x):
        # Calculate likelihood ratio
        likelihood_ratio = self.pdf(x, self.lambda1) / self.pdf(x, self.lambda2)
        # Classify based on the likelihood ratio
        if likelihood_ratio > self.threshold:
            return 'Class 1'
        else:
            return 'Class 2'

# Example parameters
lambda1 = 1.0  # Rate parameter for class 1
lambda2 = 0.5  # Rate parameter for class 2
threshold = 1.0  # Decision threshold

# Create the discrimination model
model = ExponentialDiscriminationML(lambda1, lambda2, threshold)

# Test observations
observations = [0.5, 1.5, 2.0]

# Classify each observation
for obs in observations:
    classification = model.classify(obs)
    print(f'Observation {obs} classified as: {classification}')
# Out:
# Observation 0.5 classified as: Class 1
# Observation 1.5 classified as: Class 2
# Observation 2.0 classified as: Class 2
